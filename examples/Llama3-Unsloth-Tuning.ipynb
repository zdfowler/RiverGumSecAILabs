# %%
from unsloth import FastLanguageModel
import torch
import warnings

warnings.filterwarnings('ignore')
max_seq_length = 4096

# 4bit pre quantized models
# More models at https://huggingface.co/unsloth
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",
]

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Meta-Llama-3.1-8B",
    max_seq_length = max_seq_length,
    dtype = None,
    load_in_4bit = True
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# ==((====))==  Unsloth 2024.10.2: Fast Llama patching. Transformers = 4.46.0.dev0.
#    \\   /|    GPU: NVIDIA GeForce RTX 4090. Max memory: 23.988 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.0+cu124. CUDA = 8.9. CUDA Toolkit = 12.4.
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post2. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2024.10.2 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
prompt = """
Below is an instruction that describes a task, paired with an input that provides further context.
Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

# end of sequence token
EOS_TOKEN = tokenizer.eos_token
def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # Must have EOS_TOKEN, otherwise your generation will go on forever!
        text = prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass

from datasets import load_dataset
dataset = load_dataset("yahma/alpaca-cleaned", split = "train")
dataset = dataset.map(formatting_prompts_func, batched = True,)

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        # num_train_epochs = 1, # Set this for 1 full training run.
        max_steps = 60,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none", # Use this for WandB etc
    ),
)
# Out:
# max_steps is given, it will override any value given in num_train_epochs

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = NVIDIA GeForce RTX 4090. Max memory = 23.988 GB.
# 5.984 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 51,760 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 60
#  "-____-"     Number of trainable parameters = 41,943,040
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 01:34, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.606400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.136300</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.704600</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.952400</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.779400</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.564300</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.124100</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.284100</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.160200</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.102900</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.896000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.990900</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.901600</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.066000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.875200</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.846800</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.981300</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.326800</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.019400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.858400</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.897900</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.954800</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.973800</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.973800</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.044100</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.025300</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.024600</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.912400</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.906300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.842600</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.856700</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.861900</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.003400</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.855700</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.995000</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.875800</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.816100</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.732200</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.059100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.169000</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.897600</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.963500</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.875600</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.907400</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.968500</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.939300</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.809800</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.234000</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.836600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.052800</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>1.035900</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.893700</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.999900</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.169300</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.799500</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.993200</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.876700</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.771100</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.833600</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.882000</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
#@title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 100.4616 seconds used for training.
# 1.67 minutes used for training.
# Peak reserved memory = 7.234 GB.
# Peak reserved memory for training = 1.25 GB.
# Peak reserved memory % of max memory = 30.157 %.
# Peak reserved memory for training % of max memory = 5.211 %.

# %%
# save the model
torch.save(model.state_dict(), 'alpaca-finetuned.pth')

# %%
import json
import datasets

with open('bhis-blogs.json', 'rt') as fh:
    data = json.load(fh)

# re-format dataset
newds = []
for item in data:
    newds.append({
        'input': '',
        'instruction': 'Write a blog in the same style as this content.',
        'output': f"{item['title']}, {item['date_created_gmt']}, {item['taxonomies']}, {item['content']}"
    })
ds = datasets.Dataset.from_list(newds)
ds = ds.map(formatting_prompts_func, batched = True,)

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = ds,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        # num_train_epochs = 1, # Set this for 1 full training run.
        max_steps = 30,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none", # Use this for WandB etc
    ),
)
# Out:
# Map:   0%|          | 0/3571 [00:00<?, ? examples/s]
# Map (num_proc=2):   0%|          | 0/3571 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %%
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 3,571 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 30
#  "-____-"     Number of trainable parameters = 41,943,040
#     <div>
#
#       <progress value='30' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30/30 02:25, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.828400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.266100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.127200</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.042700</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.229500</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.292500</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.990100</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.943300</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.236900</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.278800</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.347700</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.740700</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.694500</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.552800</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.633300</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.629700</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.630600</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.378300</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.757900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.022800</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.041500</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.233800</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.201500</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>2.647000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.427600</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.949500</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.697400</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.559200</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.735200</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.515400</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=30, training_loss=1.2210648556550343, metrics={'train_runtime': 146.2987, 'train_samples_per_second': 1.64, 'train_steps_per_second': 0.205, 'total_flos': 1.1004329310633984e+16, 'train_loss': 1.2210648556550343, 'epoch': 0.0671892497200448})

# %%
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    prompt.format(
        "", # instruction
        "Describe some red teaming techniques used by Michael Allen", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 8192, use_cache = True)
tokenizer.batch_decode(outputs)
# Out:
# ["<|begin_of_text|>\nBelow is an instruction that describes a task, paired with an input that provides further context.\nWrite a response that appropriately completes the request.\n\n### Instruction:\n\n\n### Input:\nDescribe some red teaming techniques used by Michael Allen\n\n### Response:\nAs a red teamer, Michael Allen employs a variety of techniques to simulate real-world cyber threats and test the effectiveness of an organization's security defenses. Here are some of the techniques he uses:\n\n1. Social Engineering: This technique involves manipulating people into divulging sensitive information or performing actions that compromise security. Techniques used include phishing, pretexting, baiting, and tailgating.\n\n2. Vulnerability Scanning: Michael Allen uses vulnerability scanning tools to identify and exploit weaknesses in a target organization's systems and networks. This includes network scans, web application scans, and database scans.\n\n3. Penetration Testing: This involves simulating an attack on a target organization's systems and networks to identify and exploit vulnerabilities. This includes network penetration testing, web application penetration testing, and database penetration testing.\n\n4. Incident Response: Michael Allen uses incident response techniques to simulate a real-world cyber attack and test the organization's ability to respond to and contain the incident.\n\n5. Threat Intelligence: Michael Allen uses threat intelligence techniques to gather information about potential threats and vulnerabilities and use that information to inform his red teaming activities.\n\n6. Physical Security Testing: Michael Allen uses physical security testing techniques to assess the physical security of a target organization's facilities, including locks, alarms, and access controls.\n\n7. Mobile Device Security Testing: Michael Allen uses mobile device security testing techniques to assess the security of mobile devices used by employees, including smartphones and tablets.\n\n8. Cloud Security Testing: Michael Allen uses cloud security testing techniques to assess the security of cloud-based systems and services used by the target organization.\n\n9. Insider Threat Simulation: Michael Allen uses insider threat simulation techniques to assess the security of an organization's internal systems and networks and simulate the actions of a malicious insider.\n\n10. Wireless Security Testing: Michael Allen uses wireless security testing techniques to assess the security of wireless networks used by the target organization, including Wi-Fi, Bluetooth, and ZigBee.\n\nOverall, Michael Allen uses a variety of red teaming techniques to test the security of a target organization and help them improve their defenses against real-world cyber threats.<|end_of_text|>"]

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    prompt.format(
        "Continue the fibonnaci sequence.", # instruction
        "1, 1, 2, 3, 5, 8", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128)
