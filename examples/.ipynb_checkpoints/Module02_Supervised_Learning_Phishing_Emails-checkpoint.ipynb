# %% [markdown]
# <a href="https://colab.research.google.com/github/RiverGumSecurity/AILabs/blob/main/examples/PandasExample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Supervised Learning with Phishing Email Data
#
# This notebook explores core concepts and and provides examples of machine learning.  We will use phishing emails as a dataset and compare statistcal learning methods, such as Linear Regression and Support Vector Machines,as well as more sophisticated deep learning techniques with neural networks where Recurrent Neural Networks and Long Short Term Memory will be tranined and applied.

# %%
# import libraries
import numpy as np
import pandas as pd
import nltk
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import datetime
import os 
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score,f1_score,classification_report,ConfusionMatrixDisplay,confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
import warnings

# %%
# Detect GPU device
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9131915594799509157
# xla_global_id: -1
# ]

# %%
# Set random seed in notebook for consistent results
np.random.seed(42)

# %% [markdown]
# ## Dataset
#
# The dataset that will be used to train and test the different models was from https://www.kaggle.com/datasets/subhajournal/phishingemails.  It was pre-labeled as "Safe Email" or "Phishing Email".  The data will be cleaned and prepared for training machine learning models with Pandas.

# %%
# Read in the data into a Pandas dataframe
df = pd.read_csv('https://raw.githubusercontent.com/RiverGumSecurity/AILabs/main/datasets/Phishing_Email.csv')
df.head(10)
# Out:
#    Unnamed: 0                                         Email Text  \
# 0           0  re : 6 . 1100 , disc : uniformitarianism , re ...
# 1           1  the other side of * galicismos * * galicismo *...
# 2           2  re : equistar deal tickets are you still avail...
# 3           3  \nHello I am your hot lil horny toy.\n    I am...
# 4           4  software at incredibly low prices ( 86 % lower...
# 5           5  global risk management operations sally congra...
# 6           6  On Sun, Aug 11, 2002 at 11:17:47AM +0100, wint...
# 7           7  entourage , stockmogul newsletter ralph velez ...
# 8           8  we owe you lots of money dear applicant , afte...
# 9           9  re : coastal deal - with exxon participation u...
#
#        Email Type
# 0      Safe Email
# 1      Safe Email
# 2      Safe Email
# 3  Phishing Email
# 4  Phishing Email
# 5      Safe Email
# 6      Safe Email
# 7  Phishing Email
# 8  Phishing Email
# 9      Safe Email

# %%
# Print information on the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18650 entries, 0 to 18649
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  18650 non-null  int64
#  1   Email Text  18634 non-null  object
#  2   Email Type  18650 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 437.2+ KB

# %%
# Find null values in the data - these can cause issues for computation later in the notebook
df.isna().sum()
# Out:
# Unnamed: 0     0
# Email Text    16
# Email Type     0
# dtype: int64

# %%
# Drop null values in place, drop Unamed:0 column, drop duplicates
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df.dropna(inplace=True,axis=0)
df.drop_duplicates(inplace=True)

# %%
# Show the shape of the data
df.shape
# Out:
# (17538, 2)

# %%
# Display cleaned dataframe
df.head(10)
# Out:
#                                           Email Text      Email Type
# 0  re : 6 . 1100 , disc : uniformitarianism , re ...      Safe Email
# 1  the other side of * galicismos * * galicismo *...      Safe Email
# 2  re : equistar deal tickets are you still avail...      Safe Email
# 3  \nHello I am your hot lil horny toy.\n    I am...  Phishing Email
# 4  software at incredibly low prices ( 86 % lower...  Phishing Email
# 5  global risk management operations sally congra...      Safe Email
# 6  On Sun, Aug 11, 2002 at 11:17:47AM +0100, wint...      Safe Email
# 7  entourage , stockmogul newsletter ralph velez ...  Phishing Email
# 8  we owe you lots of money dear applicant , afte...  Phishing Email
# 9  re : coastal deal - with exxon participation u...      Safe Email

# %%
# Display the count of Email types, a Safe Email or a Phishing Email
df['Email Type'].value_counts()
# Out:
# Email Type
# Safe Email        10980
# Phishing Email     6558
# Name: count, dtype: int64

# %%
# Plot counts of Safe Email vs Phishing Email
df['Email Type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Email Type'>

# %% [markdown]
# Now we need to further process and clean the data. This is a binary classification problem, and we need to assign a label (a 1 or a 0) to the email categories. Then we will remove URLS and non word characters from the emails - we are interested in the similarities of the text itself.  Then we lowercase all of the characters, convert all multiple whitespace characters to single whitespace, and remove any trailing whitespaces.

# %%
# Label Email Type
lbl = LabelEncoder()
df['Email Type'] = lbl.fit_transform(df['Email Type'])

# %%
# Function to preprocess text.
def preprocess_text(text):
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = text.lower()
    text = re.sub(r'\s+', ' ', text).strip()
    return text
df['Email Text']=df['Email Text'].apply(preprocess_text)

# %%
df.head(10)
# Out:
#                                           Email Text  Email Type
# 0  re 6 1100 disc uniformitarianism re 1086 sex l...           1
# 1  the other side of galicismos galicismo is a sp...           1
# 2  re equistar deal tickets are you still availab...           1
# 3  hello i am your hot lil horny toy i am the one...           0
# 4  software at incredibly low prices 86 lower dra...           0
# 5  global risk management operations sally congra...           1
# 6  on sun aug 11 2002 at 111747am 0100 wintermute...           1
# 7  entourage stockmogul newsletter ralph velez ge...           0
# 8  we owe you lots of money dear applicant after ...           0
# 9  re coastal deal with exxon participation under...           1

# %% [markdown]
# Now we convert the text into a TF-IDF (Term Frequencey Inverse Document Frequency) matrix. This a statistical measure that evaluates how relevant a word is to a document in a collection of documents. It combines two metrics: the number of times a word appears in a document (term frequency) and the inverse document frequency of the word across the entire set of documents where each email is a document.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html
#
# The Email Type columns is then converted into a numpy array.  Data from both calculations is stored in a class object.

# %%
# Convert email text to an array of vectors, removing stop words
tf = TfidfVectorizer(stop_words='english',max_features=10000) #dimension reduction
feature_x = tf.fit_transform(df['Email Text']).toarray()

# convert the label into numpy array
y_tf = np.array(df['Email Type'])

# %%
print(type(tf))
# Out:
# <class 'sklearn.feature_extraction.text.TfidfVectorizer'>

# %% [markdown]
# In data science and traning and testing machine learning models, it is common practice to split the data into traning and validation splits.  Usually this is an 80/20 split where 80% of the data is used for training the model, and 20% is used for validation. The validation process is used to measure the accuracy of the model using various statistical measurements.

# %%
#split dataset into training and testing data groups, 80 percent training, 20 percent testing
X_tr,X_tst,y_tr,y_tst = train_test_split(feature_x,y_tf,test_size=0.2,random_state=0)

# %% [markdown]
# ## Logistic Regression
#
# Now that we have split our data into traning and validation sets, we are ready for our first machine learning model that will be able to tell if an email is phishing or not based on the text of the email.  The first model we will explore is Logistic Regression.
#
# Logistic regression is a statistical method used for binary classification, where the goal is to predict the probability that a given input belongs to one of two categories. It models the relationship between a dependent binary variable and one or more independent variables using the logistic function, producing an output between 0 and 1. This output can then be thresholded to classify the input into one of the two categories.
#
# A good explanation of how this works can be found from the good folks at StatQuest:
#
# https://www.youtube.com/watch?v=yIYKR4sgzI8
#
# We will use the SciKit Learn implmentation of the Logistic Regression algorithm:
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %% [markdown]
# ## Run Logistic Regression Model

# %%
# instantiate Logistic Regression class and fit the model to the data
lg = LogisticRegression()
lg.fit(X_tr,y_tr)

# predict whether class 0 (phishing) or class 1 (not phishing)
pred_lg = lg.predict(X_tst)

# %% [markdown]
# ## Interpret Logistic Regression Model
#
# A common way to score and interpret the results of a training and testing run of a machine learning model is with a classification report comparing the predictect results with the validation set (that was not used for training).

# %%
# Caclulate the accuracy and the f1 score of the Logistic Regression model.
# store in variables for later
lr_accu = accuracy_score(y_tst,pred_lg)*100
lr_f1 = f1_score(y_tst,pred_lg)*100

#these two lines can probably be deleted
#print("The Logistic Regression model accuracy score was " + str(lr_accu) + "\n")
#print("The Logistic Regression model F1 score was " + str(lr_f1) + "\n")

print(classification_report(y_tst,pred_lg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      1351
#            1       0.98      0.99      0.98      2157
#
#     accuracy                           0.98      3508
#    macro avg       0.98      0.98      0.98      3508
# weighted avg       0.98      0.98      0.98      3508

# %% [markdown]
# So how do we read and interpret this table?
#
# **Precision:** The ratio of correctly predicted positive observations to the total predicted positives. It answers the question: "Of all the instances that the classifier labeled as positive, how many are actually positive?"
#
# **Recall (Sensitivity):** The ratio of correctly predicted positive observations to all observations in the actual class. It answers the question: "Of all the actual positive instances, how many were correctly predicted?"
#
# **F1-Score:** The harmonic mean of precision and recall. It is a better measure than accuracy for imbalanced datasets.
#
# **Support:** The number of actual occurrences of the class in the dataset.
#
# **Accuracy:** The ratio of correctly predicted instances to the total instances. For this model, the accuracy is 0.98 (98%), meaning 98% of the predictions are correct.
#
# **Macro Average:** The average of precision, recall, and F1-score calculated for each class independently and then averaged. This metric treats all classes equally.
#
# **Weighted Average:** The average of precision, recall, and F1-score, weighted by the number of instances in each class (support). This metric is more representative when there is a class imbalance.

# %% [markdown]
# Another way tp evaluate a classification model is a confusion matrix.  This is a table showing the counts of true positive, true negative, false positive, and false negative predictions. Each row of the matrix represents the actual class, while each column represents the predicted class, allowing for a clear visualization of where the model is making correct and incorrect predictions. This helps in understanding the model's accuracy, precision, recall, and other performance metrics.
#
# **Confusion Matrix for the Logistic Regression Model**
#
# - upper left - number of emails predicted to be phishing and are actually phishing (True Positive)
#
# - upper right - number of emails predicted as not phishing that are actually phishing (False Positive)
#
# - lower left - number emails predicted to be phishing that are actually not phishing (False Negative)
#
# - lower right - number of emails predicted ast not phishing that are actually not phishing (True Negative)

# %%
clf_lg = confusion_matrix(y_tst,pred_lg)
cx_ = ConfusionMatrixDisplay(clf_lg,display_labels=['phishing_mail','safe_mail']).plot()
plt.title("confusion matrix")
plt.show()

# %% [markdown]
# ### Support Vector Machine
# https://scikit-learn.org/stable/modules/svm.html#classification

# %%
svm = LinearSVC()
svm.fit(X_tr,y_tr)

pred_svm = svm.predict(X_tst)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
svm_accu = accuracy_score(y_tst,pred_svm)*100
svm_f1 = f1_score(y_tst,pred_svm)*100


print("The SVM model accuracy score was " + str(svm_accu) + "\n")
print("The SVM model F1 score was " + str(svm_f1) + "\n")

print(classification_report(y_tst,pred_svm))

clf_lg = confusion_matrix(y_tst,pred_svm)
cx_ = ConfusionMatrixDisplay(clf_lg,display_labels=['phishing_mail','safe_mail']).plot()
plt.title("confusion matrix")
plt.show()
# Out:
# The SVM model accuracy score was 98.46066134549602
#
# The SVM model F1 score was 98.7505784359093
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1351
#            1       0.99      0.99      0.99      2157
#
#     accuracy                           0.98      3508
#    macro avg       0.98      0.98      0.98      3508
# weighted avg       0.98      0.98      0.98      3508

# %% [markdown]
# ## Multinomial Naive Bayes
# https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html#:~:text=The%20multinomial%20Naive%20Bayes%20classifier,tf%2Didf%20may%20also%20work.

# %%
nb = MultinomialNB()
nb.fit(X_tr,y_tr)
# Out:
# MultinomialNB()

# %%
pred_nav = nb.predict(X_tst)
nb_accu = accuracy_score(y_tst,pred_nav)*100
nb_f1 = f1_score(y_tst,pred_nav)*100

print("The Naive Bayes model accuracy score was " + str(nb_accu) + "\n")
print("The Maive Bayes model F1 score was " + str(nb_f1) + "\n")

print(classification_report(y_tst,pred_nav))
# Out:
# The Naive Bayes model accuracy score was 97.51995438996579
#
# The Maive Bayes model F1 score was 97.98936907788305
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      1351
#            1       0.98      0.98      0.98      2157
#
#     accuracy                           0.98      3508
#    macro avg       0.97      0.97      0.97      3508
# weighted avg       0.98      0.98      0.98      3508

# %% [markdown]
# Confusion Matrix
# upper left - number of emails predicted to be phishing and are actually phishing (True Positive)
# upper right - number of emails predicted as not phishing that are actually phishing (False Positive)
# lower left - number emails predicted to be phishing that are actually not phishing (False Negative)
# lower right - number of emails predicted ast not phishing that are actually not phishing (True Negative)

# %%
clf_nav = confusion_matrix(y_tst,pred_nav)
cx_ = ConfusionMatrixDisplay(clf_nav,display_labels=['phishing_mail','safe_mail']).plot()
plt.show()

# %% [markdown]
# ## Neural Networks

# %%
max_len = 150 #Fixed the length of each vector

tk = Tokenizer()

# Process the text

tk.fit_on_texts(df['Email Text'])
sequences = tk.texts_to_sequences(df['Email Text'])
vector = pad_sequences(sequences,padding='post', maxlen=max_len)

# %%
len(vector)
# Out:
# 17538

# %%
len(tk.word_index) + 1
# Out:
# 182317

# %%
max_features=10000

# %%
#convert feature vector and label into array
X = np.array(vector)
y = np.array(df['Email Type'])

# %%
x_train, x_test, y_train, y_test = train_test_split(vector,df['Email Type'], test_size=0.2, random_state =0)

# %% [markdown]
# Simple RNN

# %%
model_srnn = Sequential() # Sequential() API
model_srnn.add(Embedding(len(tk.word_index)+1,50))
model_srnn.add(SimpleRNN(units=100))
model_srnn.add(Dropout(0.5))
model_srnn .add(Dense(1, activation='sigmoid'))

# %%
model_srnn.compile(loss='binary_crossentropy' , optimizer='adam', metrics=['accuracy'])

# %%
historical_srnn  = model_srnn.fit(x_train,y_train, epochs=15, batch_size=16, validation_data=(x_test,y_test))
# Out:
# Epoch 1/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.5642 - loss: 0.7054 - val_accuracy: 0.6203 - val_loss: 0.6466
# Epoch 2/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 19s 22ms/step - accuracy: 0.6266 - loss: 0.6419 - val_accuracy: 0.6873 - val_loss: 0.5588
# Epoch 3/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 19s 22ms/step - accuracy: 0.7168 - loss: 0.5198 - val_accuracy: 0.7221 - val_loss: 0.4984
# Epoch 4/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7489 - loss: 0.4598 - val_accuracy: 0.6981 - val_loss: 0.5095
# Epoch 5/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7624 - loss: 0.4364 - val_accuracy: 0.7044 - val_loss: 0.5425
# Epoch 6/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7347 - loss: 0.4908 - val_accuracy: 0.7243 - val_loss: 0.4953
# Epoch 7/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7808 - loss: 0.4488 - val_accuracy: 0.6713 - val_loss: 0.6255
# Epoch 8/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7259 - loss: 0.5852 - val_accuracy: 0.6964 - val_loss: 0.5770
# Epoch 9/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7282 - loss: 0.5329 - val_accuracy: 0.6987 - val_loss: 0.5425
# Epoch 10/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7447 - loss: 0.4983 - val_accuracy: 0.7030 - val_loss: 0.5347
# Epoch 11/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7482 - loss: 0.4740 - val_accuracy: 0.7132 - val_loss: 0.5248
# Epoch 12/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 19s 22ms/step - accuracy: 0.7459 - loss: 0.4611 - val_accuracy: 0.7127 - val_loss: 0.5315
# Epoch 13/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.7463 - loss: 0.4567 - val_accuracy: 0.7115 - val_loss: 0.5244
# Epoch 14/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7471 - loss: 0.4413 - val_accuracy: 0.7158 - val_loss: 0.5282
# Epoch 15/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7489 - loss: 0.4338 - val_accuracy: 0.7118 - val_loss: 0.5271

# %%
pd.DataFrame(historical_srnn.history)

pd.DataFrame(historical_srnn.history)[['accuracy', 'val_accuracy']].plot()
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')

pd.DataFrame(historical_srnn.history)[['loss', 'val_loss']].plot()
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
y_pred_prob_smp = model_srnn.predict(x_test)
y_pred_smp = (y_pred_prob_smp > 0.5).astype(int)


cnf_smp = confusion_matrix(y_test,y_pred_smp)
ax_smp = ConfusionMatrixDisplay(confusion_matrix=cnf_smp,display_labels=['phishing','normal']).plot()
plt.title("Confusion Matrix")
plt.show()
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
# Evaluate the model on the test set
srnn_loss, srnn_accu = model_srnn.evaluate(x_test, y_test, verbose=0)

srnn_accu = (srnn_accu*100)

# Display the accuracy value
print(f'The accuracy of the SRNN model on the test data set was: {srnn_accu:.4f}')
# Out:
# The accuracy of the SRNN model on the test data set was: 71.1802

# %% [markdown]
# ### LSTM

# %%
model_lstm = Sequential() # Sequential() API
model_lstm.add(Embedding(len(tk.word_index)+1,50))
model_lstm.add(LSTM(units=100))
model_lstm.add(Dropout(0.5))
model_lstm.add(Dense(1, activation='sigmoid'))

# %%
model_lstm.compile(loss='binary_crossentropy' , optimizer='adam', metrics=['accuracy'])

# %%
historical_lstm  = model_lstm.fit(x_train,y_train, epochs=15, batch_size=16, validation_data=(x_test,y_test))
# Out:
# Epoch 1/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 49s 55ms/step - accuracy: 0.6799 - loss: 0.5887 - val_accuracy: 0.9330 - val_loss: 0.2184
# Epoch 2/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 52s 59ms/step - accuracy: 0.9056 - loss: 0.2570 - val_accuracy: 0.9216 - val_loss: 0.2334
# Epoch 3/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 49s 56ms/step - accuracy: 0.9356 - loss: 0.2044 - val_accuracy: 0.9404 - val_loss: 0.2044
# Epoch 4/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 47s 53ms/step - accuracy: 0.9631 - loss: 0.1332 - val_accuracy: 0.9515 - val_loss: 0.1721
# Epoch 5/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 49s 55ms/step - accuracy: 0.9102 - loss: 0.2717 - val_accuracy: 0.9558 - val_loss: 0.1548
# Epoch 6/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 47s 53ms/step - accuracy: 0.9744 - loss: 0.0911 - val_accuracy: 0.9678 - val_loss: 0.1149
# Epoch 7/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 46s 53ms/step - accuracy: 0.9912 - loss: 0.0364 - val_accuracy: 0.9706 - val_loss: 0.1058
# Epoch 8/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 46s 53ms/step - accuracy: 0.9934 - loss: 0.0306 - val_accuracy: 0.9749 - val_loss: 0.1020
# Epoch 9/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 47s 54ms/step - accuracy: 0.9964 - loss: 0.0190 - val_accuracy: 0.9709 - val_loss: 0.1304
# Epoch 10/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 48s 55ms/step - accuracy: 0.9964 - loss: 0.0205 - val_accuracy: 0.9749 - val_loss: 0.1038
# Epoch 11/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 47s 54ms/step - accuracy: 0.9975 - loss: 0.0101 - val_accuracy: 0.9769 - val_loss: 0.0892
# Epoch 12/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 47s 54ms/step - accuracy: 0.9981 - loss: 0.0097 - val_accuracy: 0.9792 - val_loss: 0.0904
# Epoch 13/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 47s 54ms/step - accuracy: 0.9993 - loss: 0.0034 - val_accuracy: 0.9783 - val_loss: 0.1140
# Epoch 14/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 49s 56ms/step - accuracy: 0.9996 - loss: 0.0028 - val_accuracy: 0.9766 - val_loss: 0.1197
# Epoch 15/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 50s 57ms/step - accuracy: 0.9996 - loss: 0.0023 - val_accuracy: 0.9763 - val_loss: 0.1067

# %%
lstm_results = model_lstm.evaluate(x_test, y_test)
lstm_loss = lstm_results[0]  # Extract the loss from the results
lstm_accu = (lstm_results[1]*100)  # Extract the accuracy from the results

print(f"Model Loss: {lstm_loss}")
print(f"Model Accuracy: {lstm_accu}")
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9749 - loss: 0.1090
# Model Loss: 0.10666898638010025
# Model Accuracy: 97.63398170471191

# %%
y_pred_prob = model_lstm.predict(x_test)
y_pred = (y_pred_prob > 0.5).astype(int)
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step

# %%
pd.DataFrame(historical_lstm.history)

pd.DataFrame(historical_lstm.history)[['accuracy', 'val_accuracy']].plot()
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')

pd.DataFrame(historical_lstm.history)[['loss', 'val_loss']].plot()
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
cnf = confusion_matrix(y_test,y_pred)
ax = ConfusionMatrixDisplay(confusion_matrix=cnf,display_labels=['pishing','normal'])
ax.plot()
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ### Bidirectional

# %%
model_bi = Sequential() # Sequential() API
model_bi.add(Embedding(len(tk.word_index)+1,50))
model_bi.add(Bidirectional(LSTM(units=100)))
model_bi.add(Dropout(0.5))
model_bi.add(Dense(1, activation='sigmoid'))

# %%
model_bi.compile(loss='binary_crossentropy' , optimizer='adam', metrics=['accuracy'])

# %%
historical_bi  = model_bi.fit(x_train,y_train, epochs=15, batch_size=16, validation_data=(x_test,y_test))
# Out:
# Epoch 1/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 89s 101ms/step - accuracy: 0.8434 - loss: 0.3345 - val_accuracy: 0.9544 - val_loss: 0.1358
# Epoch 2/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 92s 105ms/step - accuracy: 0.9851 - loss: 0.0576 - val_accuracy: 0.9738 - val_loss: 0.0942
# Epoch 3/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 92s 105ms/step - accuracy: 0.9766 - loss: 0.0727 - val_accuracy: 0.9669 - val_loss: 0.0925
# Epoch 4/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 93s 105ms/step - accuracy: 0.9942 - loss: 0.0205 - val_accuracy: 0.9658 - val_loss: 0.1051
# Epoch 5/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 249s 284ms/step - accuracy: 0.9956 - loss: 0.0148 - val_accuracy: 0.9738 - val_loss: 0.1444
# Epoch 6/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 89s 101ms/step - accuracy: 0.9987 - loss: 0.0051 - val_accuracy: 0.9792 - val_loss: 0.0851
# Epoch 7/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 90s 102ms/step - accuracy: 0.9998 - loss: 8.4437e-04 - val_accuracy: 0.9806 - val_loss: 0.0926
# Epoch 8/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 87s 99ms/step - accuracy: 0.9999 - loss: 2.8037e-04 - val_accuracy: 0.9818 - val_loss: 0.1019
# Epoch 9/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 89s 102ms/step - accuracy: 0.9999 - loss: 2.1678e-04 - val_accuracy: 0.9803 - val_loss: 0.1239
# Epoch 10/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 87s 99ms/step - accuracy: 0.9999 - loss: 3.1994e-04 - val_accuracy: 0.9800 - val_loss: 0.1395
# Epoch 11/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 87s 99ms/step - accuracy: 0.9999 - loss: 1.1409e-04 - val_accuracy: 0.9803 - val_loss: 0.1379
# Epoch 12/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 87s 99ms/step - accuracy: 0.9998 - loss: 2.4841e-04 - val_accuracy: 0.9789 - val_loss: 0.1582
# Epoch 13/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 87s 99ms/step - accuracy: 0.9999 - loss: 2.6862e-04 - val_accuracy: 0.9664 - val_loss: 0.1431
# Epoch 14/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 88s 100ms/step - accuracy: 0.9948 - loss: 0.0159 - val_accuracy: 0.9761 - val_loss: 0.1038
# Epoch 15/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 89s 101ms/step - accuracy: 0.9988 - loss: 0.0030 - val_accuracy: 0.9772 - val_loss: 0.0953

# %%
bi_results = model_bi.evaluate(x_test, y_test)
bi_loss = bi_results[0]  # Extract the loss from the results
bi_accu = (bi_results[1]*100)  # Extract the accuracy from the results

print(f"Model Loss: {bi_loss}")
print(f"Model Accuracy: {bi_accu}")
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.9777 - loss: 0.0888
# Model Loss: 0.09526405483484268
# Model Accuracy: 97.71949648857117

# %%
y_pred_prob_bi = model_bi.predict(x_test)
y_pred_bi = (y_pred_prob_bi > 0.5).astype(int)
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step

# %%
pd.DataFrame(historical_bi.history)

pd.DataFrame(historical_bi.history)[['accuracy', 'val_accuracy']].plot()
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')

pd.DataFrame(historical_bi.history)[['loss', 'val_loss']].plot()
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
cnf_bi = confusion_matrix(y_test,y_pred_bi)
ax_bi = ConfusionMatrixDisplay(confusion_matrix=cnf_bi,display_labels=['Phishing','Normal'])
ax_bi.plot()
plt.show()

# %% [markdown]
# ### Gated Recuurent Unit

# %%
model_gru = Sequential() # Sequential() API
model_gru.add(Embedding(len(tk.word_index)+1,50))
model_gru.add(GRU(units=100))
model_gru.add(Dropout(0.5))
model_gru.add(Dense(1, activation='sigmoid'))

# %%
model_gru.compile(loss='binary_crossentropy' , optimizer='adam', metrics=['accuracy'])

# %%
model_gru.fit(x_train,y_train, epochs=15, batch_size=16, validation_data=(x_test,y_test))
# Out:
# Epoch 1/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 42s 47ms/step - accuracy: 0.6792 - loss: 0.5805 - val_accuracy: 0.9493 - val_loss: 0.1798
# Epoch 2/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - accuracy: 0.8956 - loss: 0.2496 - val_accuracy: 0.9746 - val_loss: 0.0796
# Epoch 3/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - accuracy: 0.9875 - loss: 0.0417 - val_accuracy: 0.9712 - val_loss: 0.0935
# Epoch 4/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - accuracy: 0.9964 - loss: 0.0167 - val_accuracy: 0.9766 - val_loss: 0.0869
# Epoch 5/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - accuracy: 0.9989 - loss: 0.0061 - val_accuracy: 0.9772 - val_loss: 0.0918
# Epoch 6/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - accuracy: 0.9996 - loss: 0.0025 - val_accuracy: 0.9789 - val_loss: 0.1020
# Epoch 7/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 40s 46ms/step - accuracy: 0.9996 - loss: 0.0017 - val_accuracy: 0.9795 - val_loss: 0.0918
# Epoch 8/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - accuracy: 0.9991 - loss: 0.0026 - val_accuracy: 0.9781 - val_loss: 0.1162
# Epoch 9/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - accuracy: 0.9999 - loss: 2.0440e-04 - val_accuracy: 0.9769 - val_loss: 0.1339
# Epoch 10/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - accuracy: 0.9993 - loss: 0.0028 - val_accuracy: 0.9795 - val_loss: 0.1302
# Epoch 11/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - accuracy: 0.9998 - loss: 7.0578e-04 - val_accuracy: 0.9743 - val_loss: 0.1127
# Epoch 12/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - accuracy: 1.0000 - loss: 4.5681e-04 - val_accuracy: 0.9778 - val_loss: 0.1183
# Epoch 13/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - accuracy: 0.9998 - loss: 3.1465e-04 - val_accuracy: 0.9781 - val_loss: 0.1494
# Epoch 14/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 1.0000 - loss: 1.6317e-04 - val_accuracy: 0.9789 - val_loss: 0.1396
# Epoch 15/15
# 877/877 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - accuracy: 0.9999 - loss: 3.4476e-04 - val_accuracy: 0.9800 - val_loss: 0.1517

# %%
gru_results = model_gru.evaluate(x_test, y_test)
gru_loss = gru_results[0]  # Extract the loss from the results
gru_accu = (gru_results[1]*100)  # Extract the accuracy from the results

print(f"Model Loss: {gru_loss}")
print(f"Model Accuracy: {gru_accu}")
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9797 - loss: 0.1463
# Model Loss: 0.1516750603914261
# Model Accuracy: 98.00456166267395

# %%
y_pred_prob_gru = model_gru.predict(x_test)
y_pred_gru = (y_pred_prob_gru > 0.5).astype(int)
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step

# %%
cnf_gru = confusion_matrix(y_test,y_pred_gru)
ax_gru = ConfusionMatrixDisplay(confusion_matrix=cnf_gru,display_labels=['Pishing','normal'])
ax_gru.plot()
plt.show()

# %% [markdown]
# # Comparisons

# %%
# Need to do - set up table of models and comparisons

accu_values = [lr_accu,svm_accu,nb_accu,srnn_accu,lstm_accu, bi_accu, gru_accu]
row_labels = ["Logistic Regression", "SVM", "Naive Bayes", "Simple RNN", "LSTM Neural Network", "Bidirectional Neural Network", "Gated Reccurent Unit"]
comp_df = pd.DataFrame(accu_values, columns=["accuracy"], index=row_labels)
print(comp_df)
# Out:
#                                accuracy
# Logistic Regression           97.947548
# SVM                           98.460661
# Naive Bayes                   97.519954
# Simple RNN                    71.180159
# LSTM Neural Network           97.633982
# Bidirectional Neural Network  97.719496
# Gated Reccurent Unit          98.004562

# %% [markdown]
# # Save Model

# %%
model_bi.save('model_bi_save.keras')

# %%
model_bi.export('exported_model')
# Out:
# INFO:tensorflow:Assets written to: exported_model/assets
# INFO:tensorflow:Assets written to: exported_model/assets
# Saved artifact at 'exported_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 150), dtype=tf.float32, name='keras_tensor_10')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   17932129040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   17932128848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   17932130576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   17932131344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   17932130960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   17932132496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   17932133264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   17932133072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   17932134032: TensorSpec(shape=(), dtype=tf.resource, name=None)
